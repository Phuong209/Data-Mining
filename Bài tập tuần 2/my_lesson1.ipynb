# %% [markdown]
# # “Thuc hanh tri tue nhan tao Buoi 1”
# ## “Noi dung thuc hanh”

# %% [markdown]
# ### In chu ra man hinh

# %%
# lenh 1 - xuat chu
print('Hello, Python World!')
# Out:
# Hello, Python World!

# %% [markdown]
# # "Chay ex0_hello_world.py."

# %%
# %run ex0_hello_world.py
# Out:
# Hello, Python World!

# %% [markdown]
# # "Chay ex1_calc.py"

# %%
# %run ex1_calc.py
# Out:
# Calculator Basic

# %% [markdown]
# #  "Chay ex3_circle.py"

# %%
# %run ex3_circle.py
# Out:
# Nhập bán kính r: 2
# Chu vi hình tròn = 2πr = 12.57
# Diện tích hình tròn = πr^2 = 12.57

# %% [markdown]
# # Ket Thuc
